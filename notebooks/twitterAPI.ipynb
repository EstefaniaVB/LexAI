# %%
import tweepy
import pandas as pd

# %%
consumer_key = '9umB871XoF6EuNoLyhvjGHgiW'
consumer_secret = 'Uq3JE0KdaGuLzxVxkyTe3Vr497YSM9tx27dAbWJWtVrSEkXbvh'
access_token = '966703151796629505-p2weQuTNHboVmXgZxsdglEE5OwbOlXM'
access_token_secret = 'ZLpJp7OHr02uzvU4M4njUO47Zf24yEd7vWlJJ0nVl7MbX'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
user = api.get_user('twitter')

# %%
cursor = tweepy.Cursor(api.user_timeline, id='guardian', tweet_mode="extended").items(1)

# %%
cursor

# %%
for i in cursor:
    print(dir(i))

# %%
for i in cursor:
    print(i.full_text)
# Out:
# Croatia cancel plans to stay in Scotland for Euro 2020 over Covid rules https://t.co/41D7hJCnXN

# %% [markdown]
# ### looking for tweets containing a key-word

# %%
cursor = tweepy.Cursor(api.search, q='agriculture', tweet_mode="extended").items(1)

# %%
for i in cursor:
    print(i.full_text)
# Out:
# RT @malavsatyendra5: @TheUpenYadav Thank u sir for rising agriculture students voice

# %%
number_of_tweets = 50
tweets = []
likes = []
time = []

for i in tweepy.Cursor(api.search, q='agriculture',result_type='popular', tweet_mode="extended").items(number_of_tweets):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)
    
df = pd.DataFrame({'tweets':tweets, 'likes':likes, 'time':time})
df
# Out:
#                                                tweets  likes  \
# 0   In 🇮🇳\n\n🔸Highest fuel price in world\n🔸Privat...    689
# 1   Economy, Health, Agriculture Sector in Tears &...   1249
# 2   The government under Sh @narendramodi ji has d...    469
# 3   The @narendramodi govt in the last 7 years hav...    503
# 4   Revolutionizing Indian Agriculture!\nUnder the...    173
# 5   The rains and the Kharif season are upon us. L...    419
# 6   Across the world, as the moon darkened, farmer...    499
# 7   3/3\n\n5.All government offices to function at...    173
# 8   This farm produces 30X more food per acre than...    415
# 9   The Department of Agriculture has proposed tha...    240
# 10  Two Rwandan students are studying dry-land far...     73
# 11  Attended the Introduction of new varieties of ...     76
# 12  In all sectors right from Agriculture to Natio...     88
# 13  The Agricultural Reforms made under the leader...    106
# ...

# %% [markdown]
# ### stats for tweets in a profile

# %%
number_of_tweets = 50
tweets = []
likes = []
time = []

for i in tweepy.Cursor(api.user_timeline, id='euronews', tweet_mode="extended").items(number_of_tweets):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)

# %%
tweets
# Out:
# ['In winter, Skopje, the Capital of North Macedonia, is one of the most polluted cities in Europe. https://t.co/Y1oPuzqLp8',
#  'Meet the journalist who fled Belarus hours before Ryanair diversion https://t.co/UUjyT177Lu',
#  'The murky issue of air pollution in North Macedonia https://t.co/fsTp8zPgUJ',
#  "8 of Serbia’s most beautiful hikes for the country's best views and nature https://t.co/R2mqJ99ezd",
#  'Sri Lanka: Police investigate fire on ship off Colombo https://t.co/JQfV9uA52E',
#  'The trails in the Western Balkans worth the trek https://t.co/w6FHQGU126',
#  'Carlos Ghosn: French magistrates question ex-`Renault boss in Beirut https://t.co/KBEPernLnh',
#  'Czech police recommended the indictment of Prime Minister Andrej Babis https://t.co/9KgJPgZKqX',
#  'Children share their experiences of the recent Israel-Gaza violence https://t.co/mMgoe5zGXT',
#  'Naomi Osaka withdraws from French Open after being fined for not doing media https://t.co/7LldomlmQ2',
# ...

# %%
df = pd.DataFrame({'tweets':tweets, 'likes':likes, 'time':time})

# %%
df
# Out:
#                                                tweets  likes  \
# 0   Key players from the tourism industry came tog...      5
# 1   Many of Europe’s economies are expected to tak...      7
# 2   Greece and Turkey's foreign ministers are due ...      9
# 3   A left-wing green candidate won the race for t...     40
# 4   Sicily's Mount Etna erupted again in the early...     34
# 5   RT @euronewsgreen: Built to protect the Nether...      0
# 6   RT @euronewsgreen: This is exactly why we are ...      0
# 7   Afghan staff who worked with the British milit...     17
# 8   RT @euronewsgreen: “Rewilding is not a luxury ...      0
# 9   RT @euronewstravel: Home to the Seychelles' la...      0
# 10  RT @euronewsgreen: This week is #EUGreenWeek &...      0
# 11  Did Denmark help the U.S. spy on Angela Merkel...     25
# 12  Belgium's ambassador to South Korea is being s...      7
# 13  🔥 Our childhood dreams might finally become a ...     49
# ...

# %% [markdown]
# sorting out retweets:

# %%
df = df[~df.tweets.str.contains("RT")]

# %%
df
# Out:
#                                                tweets  likes  \
# 0   Key players from the tourism industry came tog...      5
# 1   Many of Europe’s economies are expected to tak...      7
# 2   Greece and Turkey's foreign ministers are due ...      9
# 3   A left-wing green candidate won the race for t...     40
# 4   Sicily's Mount Etna erupted again in the early...     34
# 7   Afghan staff who worked with the British milit...     17
# 11  Did Denmark help the U.S. spy on Angela Merkel...     25
# 12  Belgium's ambassador to South Korea is being s...      7
# 13  🔥 Our childhood dreams might finally become a ...     49
# 14  Gunmen have abducted a large number of student...      6
# 15  British Prime Minister Boris Johnson's plans t...      8
# 16  Copa America without host country two weeks be...     12
# 17  Bulgaria cleans up its beaches by renovating i...     31
# 18  Belarusians protest outside EU representation ...     33
# ...

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# get the most liked tweets:

# %%
mostlike = df.loc[df.likes.nlargest(5).index]

# %%
mostlike
# Out:
#                                                tweets  likes  \
# 31  Protesters are calling for the president to be...    188
# 8   🔥 Our childhood dreams might finally become a ...     49
# 34  Protesters rally against President Lukashenko ...     46
# 19  Sicily's Mount Etna erupted again, releasing t...     42
# 38  Chelsea beats Manchester City 1-0, winning the...     41
#
#                   time
# 31 2021-05-30 06:42:22
# 8  2021-05-31 07:36:04
# 34 2021-05-30 05:40:23
# 19 2021-05-30 16:38:05
# 38 2021-05-29 22:09:39

# %%
for i in tweepy.Cursor(api.user_timeline, id='euronews', tweet_mode="extended").items(20):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)

# %%
api.search_tweets(q='agriculture', result_type='popular', count=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-87b33fab4f26> in <module>
# ----> 1 api.search_tweets(q='agriculture', result_type='popular', count=20)
#
# AttributeError: 'API' object has no attribute 'search_tweets'
