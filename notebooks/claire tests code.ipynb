# %%
from LexAI.eurlex import Search

# %%
search=Search()

# %%
search.build_ms('agriculture')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     233             headers["User-Agent"] = _get_default_user_agent()
# --> 234         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     235
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/http/client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     199     def connect(self):
# --> 200         conn = self._new_conn()
#     201         self._prepare_conn(conn)
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x114edc370>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=7700): Max retries exceeded with url: /indexes/eurlex/documents (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x114edc370>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/meilisearch/_httprequests.py in send_request(self, http_method, path, body)
#      29             else:
# ---> 30                 request = http_method(
#      31                     request_path,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=7700): Max retries exceeded with url: /indexes/eurlex/documents (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x114edc370>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# The above exception was the direct cause of the following exception:
#
# MeiliSearchCommunicationError             Traceback (most recent call last)
# <ipython-input-3-f4ba480a567d> in <module>
# ----> 1 search.build_ms('agriculture')
#
# ~/code/EstefaniaVB/LexAI/LexAI/eurlex.py in build_ms(self, query, pages, index)
#      60     def build_ms(self, query, pages=10, index='eurlex'):
#      61         results = self.search_many(query, pages)
# ---> 62         self.client.index(index).add_documents(results)
#      63
#      64     def query_ms(self, query, index='eurlex'):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/meilisearch/index.py in add_documents(self, documents, primary_key)
#     328             primary_key = urllib.parse.urlencode({'primaryKey': primary_key})
#     329             url = f'{self.config.paths.index}/{self.uid}/{self.config.paths.document}?{primary_key}'
# --> 330         return self.http.post(url, documents)
#     331
#     332     def update_documents(self, documents, primary_key=None):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/meilisearch/_httprequests.py in post(self, path, body)
#      45
#      46     def post(self, path, body=None):
# ---> 47         return self.send_request(requests.post, path, body)
#      48
#      49     def put(self, path, body=None):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/meilisearch/_httprequests.py in send_request(self, http_method, path, body)
#      39             raise MeiliSearchTimeoutError(err) from err
#      40         except requests.exceptions.ConnectionError as err:
# ---> 41             raise MeiliSearchCommunicationError(err) from err
#      42
#      43     def get(self, path):
#
# MeiliSearchCommunicationError: MeiliSearchCommunicationError, HTTPConnectionPool(host='127.0.0.1', port=7700): Max retries exceeded with url: /indexes/eurlex/documents (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x114edc370>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
import pandas as pd

# %%
from LexAI.twitterAPI import twitter_query

# %%
tweets=twitter_query('agriculture',20)

# %%
tweets.dtypes
# Out:
# user               object
# date               object
# text               object
# favorite_count      int64
# user_loc           object
# followers_count     int64
# lang               object
# user_desc          object
# hashtags           object
# dtype: object

# %%
tweets
# Out:
#                user                            date  \
# 0        moreaujb23  Tue Jun 01 06:33:16 +0000 2021
# 1    SitaramYechury  Mon May 31 16:41:35 +0000 2021
# 2              lobs  Mon May 31 18:04:07 +0000 2021
# 3      Earthjustice  Mon May 31 13:00:01 +0000 2021
# 4                AP  Tue Jun 01 09:20:23 +0000 2021
# 5        ValaAfshar  Mon May 31 00:57:59 +0000 2021
# 6           PRupala  Mon May 31 13:19:27 +0000 2021
# 7      PatriceRoyTJ  Mon May 31 22:41:56 +0000 2021
# 8   StateHouseKenya  Mon May 31 11:06:34 +0000 2021
# 9    CMOMaharashtra  Sun May 30 18:05:24 +0000 2021
# 10     Anne_Hidalgo  Mon May 31 15:42:09 +0000 2021
# 11     MumbaiPolice  Mon May 31 05:18:02 +0000 2021
# 12         IFFCO_PR  Mon May 31 13:16:09 +0000 2021
# 13     NationAfrica  Mon May 31 07:30:00 +0000 2021
# 14   TV9Bharatvarsh  Mon May 31 08:27:08 +0000 2021
#
#                                                  text  favorite_count  \
# 0   Ces gens sont nostalgiques d'une agriculture q...             910
# 1   British: Destruction of economy &amp; agricult...             308
# 2   Les scientifiques alertent : face au déclin de...              92
# 3   We’re suing the federal government for illegal...             162
# 4   Thousands of Australian meat workers had no wo...             126
# 5   This farm produces 30X more food per acre than...             425
# 6   Attended the Introduction of new varieties of ...             143
# 7   Entassés dans des logements infestés de moisis...              71
# 8   2/3 The two East African leaders announced ren...             179
# 9   The rains and the Kharif season are upon us. L...             446
# 10  Après Rouen et avant Paris cet automne, nous é...             134
# 11  3/3\n\n5.All government offices to function at...             186
# 12  IFFCO Nano Urea Liquid ensures residue-free, p...             172
# 13  Youths’ rejection of agriculture hindering Ken...             123
# 14  नैनो यूरिया लिक्विड के इस्तेमाल से फसल उपज में...             184
#
#                user_loc  followers_count lang  \
# 0               Ceyroux            19625   fr
# 1                                1043661   en
# 2                 Paris          1443618   fr
# 3          Planet Earth           190549   en
# 4                Global         15163959   en
# 5                Boston           565345   en
# 6      New Delhi, India           411137   en
# 7   Mtl, Québec, Canada           138637   fr
# 8               Nairobi          1352643   en
# 9    Mantralaya, Mumbai          2802420   en
# 10                Paris          1514299   fr
# 11        Mumbai, India          5073551   en
# 12     New Delhi, India            18556   en
# 13                Kenya          2417010   en
# 14         Noida, India           147817   hi
#
#                                             user_desc hashtags
# 0   👨‍🌾🏛️Député paysan de la Creuse #LREM📣Porte-pa...       []
# 1   Comrade, Communist Party of India (Marxist). F...       []
# 2   Compte officiel de L'Obs 🗞️\nFacebook 👉 /lenou...       []
# 3               Because the earth needs a good lawyer       []
# 4   News from The Associated Press, and a taste of...       []
# 5   Chief Digital Evangelist @Salesforce | Columni...       []
# 6   Union Minister of the State - Agriculture & Fa...       []
# 7   Chef d'antenne 17h RDI, TJ18h Radio-Canada, sp...       []
# 8                                                           []
# 9         Office of the Chief Minister of Maharashtra       []
# 10  Maire de @Paris | Présidente de l'@AIMFrancoph...       []
# 11  Official account of Mumbai Police. For any eme...       []
# 12  Farmers Cooperative, largest manufacturer & ma...       []
# 13  We are Nation. For customer care, 📨 support@na...       []
# 14  Official handle of National Hindi News Channel...       []

# %%
tweets['date']=pd.to_datetime(tweets['date']).dt.date

# %%
tweet_date = tweets.groupby(tweets['date'])['favorite_count'].count()
tweet_date.plot(kind='bar',figsize=(10,5));

# %%
most_tweets_loc=' '.join(tweets['user_loc']).lower().split()

# %%
from collections import Counter
counts = Counter(most_tweets_loc)
counts
# Out:
# Counter({'ceyroux': 1,
#          'paris': 2,
#          'planet': 1,
#          'earth': 1,
#          'boston': 1,
#          'new': 1,
#          'delhi,': 1,
#          'india': 1,
#          'mtl,': 1,
#          'québec,': 1,
#          'canada': 1,
#          'nairobi': 1,
#          'mantralaya,': 1,
#          'mumbai': 1})

# %%
most_tweets_loc=pd.DataFrame(most_tweets_loc).reset_index()['index'][0].upper()

# %%
most_tweets_loc
# Out:
# 'INDIA'

# %%
tweet_likes=tweets['favorite_count'].sum()
tweet_followers=tweets['followers_count'].sum()

# %%
tweet_likes
# Out:
# 2121

# %%
tweet_followers
# Out:
# 14535309

# %%
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware
from LexAI.twitterAPI import twitter_query

#from predictions import get_prediction
#from consultations import get_consultation
#from twitterapi import get_tweet_volume

app = FastAPI()

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # Allows all origins
    allow_credentials=True,
    allow_methods=["*"],  # Allows all methods
    allow_headers=["*"],  # Allows all headers
)

# Create root endpoint
@app.get("/")
def index():
    return {"greeting": "Hello Estefania"}

# Predict endpoint
@app.get("/predict")
def predict(keyword):
    #PSEUDO-CODE
    #Regulations list
        #regulations=get_regulation(keyword)
    #Consultations list
        #consultations=get_consultation(keyword)
    #Twitter list
    tweets=twitter_query(keyword,10)
    #tweet_likes=tweets['favorite_count'].sum()
    #tweet_followers=tweets['followers_count'].sum()
    #return regulations,consultations,tweet_volume

    # print keyword entered by user
    return tweets

# %%
predict('agriculture')
# Out:
#               user                            date  \
# 0       moreaujb23  Tue Jun 01 06:33:16 +0000 2021
# 1   SitaramYechury  Mon May 31 16:41:35 +0000 2021
# 2             lobs  Mon May 31 18:04:07 +0000 2021
# 3     Earthjustice  Mon May 31 13:00:01 +0000 2021
# 4       ValaAfshar  Mon May 31 00:57:59 +0000 2021
# 5          PRupala  Mon May 31 13:19:27 +0000 2021
# 6     PatriceRoyTJ  Mon May 31 22:41:56 +0000 2021
# 7  StateHouseKenya  Mon May 31 11:06:34 +0000 2021
# 8   CMOMaharashtra  Sun May 30 18:05:24 +0000 2021
# 9     Anne_Hidalgo  Mon May 31 15:42:09 +0000 2021
#
#                                                 text  favorite_count  \
# 0  Ces gens sont nostalgiques d'une agriculture q...             887
# 1  British: Destruction of economy &amp; agricult...             307
# 2  Les scientifiques alertent : face au déclin de...              92
# 3  We’re suing the federal government for illegal...             161
# 4  This farm produces 30X more food per acre than...             424
# 5  Attended the Introduction of new varieties of ...             142
# 6  Entassés dans des logements infestés de moisis...              68
# 7  2/3 The two East African leaders announced ren...             178
# 8  The rains and the Kharif season are upon us. L...             444
# 9  Après Rouen et avant Paris cet automne, nous é...             132
#
#               user_loc  followers_count lang  \
# 0              Ceyroux            19625   fr
# 1                               1043649   en
# 2                Paris          1443614   fr
# 3         Planet Earth           190550   en
# 4               Boston           565304   en
# 5     New Delhi, India           411137   en
# 6  Mtl, Québec, Canada           138633   fr
# 7              Nairobi          1352606   en
# 8   Mantralaya, Mumbai          2802248   en
# 9                Paris          1514292   fr
#
#                                            user_desc hashtags
# 0  👨‍🌾🏛️Député paysan de la Creuse #LREM📣Porte-pa...       []
# 1  Comrade, Communist Party of India (Marxist). F...       []
# 2  Compte officiel de L'Obs 🗞️\nFacebook 👉 /lenou...       []
# 3              Because the earth needs a good lawyer       []
# 4  Chief Digital Evangelist @Salesforce | Columni...       []
# 5  Union Minister of the State - Agriculture & Fa...       []
# 6  Chef d'antenne 17h RDI, TJ18h Radio-Canada, sp...       []
# 7                                                          []
# 8        Office of the Chief Minister of Maharashtra       []
# 9  Maire de @Paris | Présidente de l'@AIMFrancoph...       []
